# %%
import numpy as np
import matplotlib.pyplot as plt

import matplotlib
matplotlib.rcParams['text.latex.preamble'] = r'\usepackage{amsmath}'
matplotlib.rc('text', usetex = True)

# %% [markdown]
# # Problem 6

# %%
def H(x):
    if x >= 0: return 1
    if x <  0: return 0

# %%
nrows,ncols = 1,2
fig,ax = plt.subplots(nrows=nrows,ncols=ncols,figsize=(7*ncols,5*nrows))

x = np.linspace(-4,4,500)
f = np.array([-H(_+1) + 2*H(_) - H(_-1) for _ in x])

ax[0].plot(x,f,'k')
ax[0].set_xlabel(r'$x$',size=20)
ax[0].set_ylabel(r'$f(x)$',size=20)
ax[0].tick_params(axis='both',which='major',direction='in',labelsize=20)


k = np.linspace(-10,10,500)
F = -2*np.sin(k)/k

ax[1].plot(k,F,'k')
ax[1].set_xlabel(r'$k$',size=20)
ax[1].set_ylabel(r'$\widehat{f}(k)$',size=20)
ax[1].tick_params(axis='both',which='major',direction='in',labelsize=20)

plt.tight_layout()
fig.savefig('prob6.pdf',bbox_inches='tight')
plt.show()
